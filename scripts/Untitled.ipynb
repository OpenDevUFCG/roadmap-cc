# %%
import pandas as pd

# %%
df = pd.read_csv('../data/disciplinas-ppc-2017.csv')
df
# Out:
#      codigo                                               nome  \
# 0   1411311  Fundamentos de Matemática para Ciência da Comp...
# 1   1411167                                      Programação I
# 2   1411180                       Laboratório de Programação I
# 3   1411174                            Introdução à Computação
# 4   1411312  Fundamentos de Matemática para Ciência da Comp...
# 5   1109103                  Cálculo Diferencial e Integral I
# 6   1411168                                     Programação II
# 7   1411181                      Laboratório de Programação II
# 8   1109049                                   Álgebra Linear I
# 9   1109053                 Cálculo Diferencial e Integral II
# 10  1411304                                  Teoria dos Grafos
# 11  1411307                             Lógica para Computação
# 12  1411305                                 Estrutura de Dados
# 13  1411306                  Laboratório de Estrutura de Dados
# ...
